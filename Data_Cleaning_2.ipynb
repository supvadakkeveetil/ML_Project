# %% [markdown]
# # Data Exploration and Cleaning

# %% [markdown]
# ###### 1. Import Libraries and dependencies

# %%
# Importing the Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import datetime as dt
from datetime import date

# %%
#Use the fixed processed_data_2 and processed_data_4 files and processed_data_3 files. (Have fixed the Stream Counts that were missing or had incorrect values)

# %% [markdown]
# ###### 2. Load data into the Dataframe from Excel /CSV files

# %%
#Reading data from CSV and creating a Pandas Data Frame
spotify_data_1 ="data/processed_data_1.csv" 
df1 = pd.read_csv(spotify_data_1)
spotify_data_2 ="data/processed_data_2.csv" 
df2 = pd.read_csv(spotify_data_2)
spotify_data_3 ="data/processed_data_3.csv" 
df3 = pd.read_csv(spotify_data_3)
spotify_data_4 ="data/processed_data_4.csv" 
df4 = pd.read_csv(spotify_data_4)
spotify_df= pd.concat([df1,df2,df3,df4], ignore_index=True)

# %% [markdown]
# ###### 3. Preliminary Data Examination

# %%
#Checking the data in the data frame and its structure
spotify_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... loudness  mode  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -2.634     1
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -4.969     1
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -3.432     0
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -3.778     1
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -4.672     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0583        0.1020          0.000000    0.0653    0.518  122.036
# 1       0.0373        0.0724          0.004210    0.3570    0.693   99.972
# 2       0.0742        0.0794          0.000023    0.1100    0.613  124.008
# 3       0.1020        0.0287          0.000009    0.2040    0.277  121.956
# 4       0.0359        0.0803          0.000000    0.0833    0.725  123.976
#
#    duration_ms  Stream count
# 0       194754    36,892,097
# 1       162600    26,063,851
# 2       176616    70,546,338
# 3       169093    11,862,340
# 4       189052    63,578,139
#
# [5 rows x 24 columns]

# %%
#Checking for the datatypes of the values in the df
spotify_df.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# Stream count                 object
# dtype: object

# %%
#check for missing values
print(spotify_df.isnull().sum())
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# Stream count                0
# dtype: int64

# %% [markdown]
# ###### 4. Data Cleaning

# %%
spotify_df.rename(columns= {'Stream count' : 'stream_count'},inplace=True)

# %%
# Converting Stream count into float 
spotify_df['stream_count']=spotify_df['stream_count'].str.replace(',','')

# %%
spotify_df['stream_count']=spotify_df['stream_count'].astype(float)

# %%
spotify_df.shape
# Out:
# (32829, 24)

# %%
spotify_df.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# stream_count                float64
# dtype: object

# %%
#drop null values
spotify_new= spotify_df.dropna()

# %%
# Return number of rows x columns
spotify_new.shape
# Out:
# (32824, 24)

# %%
#converting duration from ms to seconds
spotify_new['duration_sec']= spotify_new['duration_ms'].apply(lambda x: x/1000)
# Out:
# /Users/abhilashpadavannil/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
spotify_new.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... mode  speechiness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0583
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0373
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.0742
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.1020
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0359
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.1020          0.000000    0.0653    0.518  122.036       194754
# 1        0.0724          0.004210    0.3570    0.693   99.972       162600
# 2        0.0794          0.000023    0.1100    0.613  124.008       176616
# 3        0.0287          0.000009    0.2040    0.277  121.956       169093
# 4        0.0803          0.000000    0.0833    0.725  123.976       189052
#
#    stream_count  duration_sec
# 0    36892097.0       194.754
# 1    26063851.0       162.600
# 2    70546338.0       176.616
# 3    11862340.0       169.093
# 4    63578139.0       189.052
#
# [5 rows x 25 columns]

# %%
# drop unnecessary columns
spotify_new = spotify_new.drop(['duration_ms'],axis=1)
spotify_new.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... loudness  mode  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -2.634     1
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -4.969     1
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -3.432     0
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -3.778     1
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   -4.672     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0583        0.1020          0.000000    0.0653    0.518  122.036
# 1       0.0373        0.0724          0.004210    0.3570    0.693   99.972
# 2       0.0742        0.0794          0.000023    0.1100    0.613  124.008
# 3       0.1020        0.0287          0.000009    0.2040    0.277  121.956
# 4       0.0359        0.0803          0.000000    0.0833    0.725  123.976
#
#    stream_count  duration_sec
# 0    36892097.0       194.754
# 1    26063851.0       162.600
# 2    70546338.0       176.616
# 3    11862340.0       169.093
# 4    63578139.0       189.052
#
# [5 rows x 24 columns]

# %%
duplicates = spotify_new.duplicated(subset=['track_id'])
df_with_duplicates = spotify_new[duplicates]
print(df_with_duplicates)
# Out:
#                      track_id  \
# 1299   1HfMVBKM75vxSfsQ5VefZ5
# 1300   2b8fOow8UzyDFAE27YhOZM
# 1304   7qEHsqek33rTcFNT9PFqLf
# 1305   6v3KW9xbzN5yKLt9YKDYA2
# 1307   6cy3ki60hLwimwIje7tALf
# ...                       ...
# 32780  1mzGywacjpeik00PVLBPpF
# 32790  1nas007nDbzLwDGwvMdz79
# 32795  65hRZOQkVjmBdusz1N7aOv
# 32801  2KlZexJjJPuNWcN5uAG1GU
# 32805  5QcSDOm6mcvFDl7KBT1fHv
#
#                                               track_name         track_artist  \
# 1299                                 Lose You To Love Me         Selena Gomez
# 1300                                            Memories             Maroon 5
# 1304                                   Someone You Loved        Lewis Capaldi
# 1305                                            Señorita         Shawn Mendes
# 1307                           RITMO (Bad Boys For Life)  The Black Eyed Peas
# ...                                                  ...                  ...
# 32780  All of Me (Tiësto's Birthday Treatment Remix) ...          John Legend
# 32790                                    How You Love Me                 3LAU
# 32795                                     Save The World  Swedish House Mafia
# 32801                                  Gold (feat. Yuna)       Adventure Club
# 32805             Spaceman - Carnage Festival Trap Remix             Hardwell
#
#        track_popularity          track_album_id  \
# 1299                 93  3tBkjgxDqAwss76O1YHsSY
# 1300                 98  3nR9B40hYLKLcR0Eph3Goc
# 1304                 94  5658aM19fA3JVwTK6eQX70
# 1305                 88  0xzScN8P3hQAz3BT3YYX5w
# 1307                 96  6EobpC5SDFy5DF50dWNVGF
# ...                 ...                     ...
# 32780                64  4c2rSdHI9WUXn0zyXoWtbB
# 32790                52  0IsgaoqRfJAJ6wojxWDZ7C
# 32795                67  728voOLBbJUBgK2vooghcS
# 32801                 1  2DVyzKYzqlQo4uTJLVtvBt
# 32805                54  0GjLUjalniPkdkafJnkNFz
#
#                                         track_album_name  \
# 1299                                 Lose You To Love Me
# 1300                                            Memories
# 1304             Divinely Uninspired To A Hellish Extent
# 1305                               Shawn Mendes (Deluxe)
# 1307                           RITMO (Bad Boys For Life)
# ...                                                  ...
# 32780  All of Me (Tiësto's Birthday Treatment Remix) ...
# 32790                                    How You Love Me
# 32795                                     Save The World
# 32801                            Calling All Heroes - EP
# 32805             Spaceman (Carnage Festival Trap Remix)
#
#       track_album_release_date  \
# 1299                2019-10-23
# 1300                2019-09-20
# 1304                2019-05-17
# 1305                2019-06-19
# 1307                2019-10-12
# ...                        ...
# 32780                  2/25/14
# 32790                   1/1/14
# 32795                  5/13/11
# 32801                 10/22/13
# 32805                 12/29/12
#
#                                          playlist_name  \
# 1299   Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1300   Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1304   Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1305   Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1307   Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# ...                                                ...
# 32780                                  ♥ EDM LOVE 2020
# 32790                                  ♥ EDM LOVE 2020
# 32795                                  ♥ EDM LOVE 2020
# 32801                                  ♥ EDM LOVE 2020
# 32805                                  ♥ EDM LOVE 2020
#
#                   playlist_id playlist_genre  ... loudness  mode  speechiness  \
# 1299   46Cl6dmeiylK6TRGXr7hHe            pop  ...   -9.005     1       0.0438
# 1300   46Cl6dmeiylK6TRGXr7hHe            pop  ...   -7.209     1       0.0546
# 1304   46Cl6dmeiylK6TRGXr7hHe            pop  ...   -5.679     1       0.0319
# 1305   46Cl6dmeiylK6TRGXr7hHe            pop  ...   -6.049     0       0.0290
# 1307   46Cl6dmeiylK6TRGXr7hHe            pop  ...   -7.037     0       0.0657
# ...                       ...            ...  ...      ...   ...          ...
# 32780  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   -6.253     0       0.0283
# 32790  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   -3.648     1       0.0839
# 32795  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   -7.598     1       0.0474
# 32801  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   -4.893     0       0.0413
# 32805  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   -8.976     1       0.0777
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 1299       0.576000           0.00000    0.2100   0.0916  101.993
# 1300       0.837000           0.00000    0.0822   0.5750   91.019
# 1304       0.751000           0.00000    0.1050   0.4460  109.891
# 1305       0.039200           0.00000    0.0828   0.7490  116.967
# 1307       0.033400           0.00084    0.2370   0.6670  104.994
# ...             ...               ...       ...      ...      ...
# 32780      0.000151           0.00165    0.0745   0.1790  127.986
# 32790      0.183000           0.00000    0.3400   0.2860  127.961
# 32795      0.014400           0.00000    0.0759   0.4000  126.879
# 32801      0.031900           0.00536    0.1280   0.1890  145.022
# 32805      0.023500           0.76800    0.1010   0.2380  139.987
#
#        stream_count  duration_sec
# 1299   1.180717e+09       206.459
# 1300   1.933147e+09       189.486
# 1304   3.252710e+09       182.161
# 1305   2.657803e+09       190.800
# 1307   9.437753e+08       221.714
# ...             ...           ...
# 32780  2.444408e+08       251.613
# 32790  5.037774e+07       210.469
# 32795  2.115583e+08       213.338
# 32801  3.020578e+07       257.045
# 32805  3.918512e+07       234.160
#
# [4476 rows x 24 columns]

# %%
# duplicate tracks
dupli = spotify_new[spotify_new['track_id'].duplicated()]['track_id']
print(f'Number of duplicated tracks {len(dupli)}.')
# Out:
# Number of duplicated tracks 4476.

# %%
# Get today's date
today = date.today()

# Calculate months elapsed (consider year difference too)
spotify_new['months'] = (today.year - pd.to_datetime(spotify_new['track_album_release_date']).dt.year) * 12 + \
                             (today.month - pd.to_datetime(spotify_new['track_album_release_date']).dt.month)


spotify_new.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... mode  speechiness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0583
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0373
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.0742
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.1020
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0359
#
#    acousticness  instrumentalness  liveness  valence    tempo  stream_count  \
# 0        0.1020          0.000000    0.0653    0.518  122.036    36892097.0
# 1        0.0724          0.004210    0.3570    0.693   99.972    26063851.0
# 2        0.0794          0.000023    0.1100    0.613  124.008    70546338.0
# 3        0.0287          0.000009    0.2040    0.277  121.956    11862340.0
# 4        0.0803          0.000000    0.0833    0.725  123.976    63578139.0
#
#    duration_sec  months
# 0       194.754      57
# 1       162.600      51
# 2       176.616      56
# 3       169.093      56
# 4       189.052      60
#
# [5 rows x 25 columns]

# %%
# drop columns not needed
#dropping track_album_id,track_album_name,track_album_release_date,playlist_name,playlist_id
spotify_new = spotify_new.drop(['track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id'], axis=1)

# %%
spotify_new.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity playlist_genre playlist_subgenre  \
# 0        Ed Sheeran                66            pop         dance pop
# 1          Maroon 5                67            pop         dance pop
# 2      Zara Larsson                70            pop         dance pop
# 3  The Chainsmokers                60            pop         dance pop
# 4     Lewis Capaldi                69            pop         dance pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  stream_count  duration_sec  \
# 0          0.000000    0.0653    0.518  122.036    36892097.0       194.754
# 1          0.004210    0.3570    0.693   99.972    26063851.0       162.600
# 2          0.000023    0.1100    0.613  124.008    70546338.0       176.616
# 3          0.000009    0.2040    0.277  121.956    11862340.0       169.093
# 4          0.000000    0.0833    0.725  123.976    63578139.0       189.052
#
#    months
# 0      57
# 1      51
# 2      56
# 3      56
# 4      60

# %%
spotify_new.dtypes
# Out:
# track_id              object
# track_name            object
# track_artist          object
# track_popularity       int64
# playlist_genre        object
# playlist_subgenre     object
# danceability         float64
# energy               float64
# key                    int64
# loudness             float64
# mode                   int64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# stream_count         float64
# duration_sec         float64
# months                 int64
# dtype: object

# %%
# Saving the file , keeping the duplicate track ids as some of the other parameters differ
spotify_new.to_csv('data/processed_data_cleaned.csv',index=False)

# %%
#Incase we need to delete the duplicates use code below

# %%
#Drop Duplicates on track_id (duplicates on track id's but then the other parameters are different)
#spotify_final=spotify_new.drop_duplicates('track_id',keep='first')

# %%
#Save the cleaned df to a CSV/Excel file for analysis (if dropping duplicates)
#spotify_final.to_csv('data/processed_data_final.csv',index=False)
